# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.datasets import load_sample_images
from functools import partial
# Out:
# 2024-11-04 17:00:43.587322: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
images = load_sample_images()['images']

# %%
plt.imshow(images[1])

# %%
temple = images[0]
flower = images[1]

temple = tf.expand_dims(temple, axis = 0)
flower = tf.expand_dims(flower, axis = 0)

# %%
Maxpool2D = partial(tf.keras.layers.MaxPool2D, pool_size = 2)

# %%
plt.imshow(final_images[0])

# %%
Maxpool2D_fourth = partial(tf.keras.layers.MaxPool2D, pool_size = 4)

# %%
final_images = Maxpool2D_fourth()(flower)

# %%
plt.imshow(final_images[0])
